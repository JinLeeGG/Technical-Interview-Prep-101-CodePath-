# %% [markdown]
# <a href="https://colab.research.google.com/github/JinLeeGG/Technical_Interview_Prep102_CodePath/blob/main/Unit2%20(Dictionary%20%26%20Sets)/Standard_Problem_Set_Version_1(Session2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def most_endangered(species_list):
    most = species_list[0]

    for species in species_list[1:]:
        if species["population"] < most["population"]:
            most = species

    return most.get("name")

# %%
species_list = [
    {"name": "Amur Leopard",
     "habitat": "Temperate forests",
     "population": 84
    },
    {"name": "Javan Rhino",
     "habitat": "Tropical forests",
     "population": 72
    },
    {"name": "Vaquita",
     "habitat": "Marine",
     "population": 10
    }
]

print(most_endangered(species_list))
# Out:
# Vaquita

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def count_endangered_species(endangered_species, observed_species):
    count = 0
    for species in observed_species:
      if species in endangered_species:
        count += 1

    return count

# %%
endangered_species1 = "aA"
observed_species1 = "aAAbbbb"

endangered_species2 = "z"
observed_species2 = "ZZ"

print(count_endangered_species(endangered_species1, observed_species1))
print(count_endangered_species(endangered_species2, observed_species2))
# Out:
# 3
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def navigate_research_station(station_layout, observations):
  a = dict()
  for index, char in enumerate(station_layout):
      a[char] = index

  # 첫 시간값 -> 첫번째 캐릭터의 값으로 설정
  count = a[observations[0]]
  print(f"Initional observations 0: {count}")

  # 3. 순서대로 이동 거리 계산
  for i in range(len(observations) - 1):
      # 현재위치값 찾기
      current_pos = a[observations[i]]
      # 다음위치값 찾기
      next_pos = a[observations[i+1]]
      # 시간계산해서 더하기
      count += abs(current_pos - next_pos)

  return count

# %%
station_layout1 = "pqrstuvwxyzabcdefghijklmno"
observations1 = "wildlife"

station_layout2 = "abcdefghijklmnopqrstuvwxyz"
observations2 = "cba"

print(navigate_research_station(station_layout1, observations1))
print(navigate_research_station(station_layout2, observations2))
# Out:
# Initional observations 0: 7
# 45
# Initional observations 0: 2
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def prioritize_observations(observed_species, priority_species):
    sortedList = []
    ps = priority_species

    for i in ob:
        if

# %%
observed_species1 = ["🐯", "🦁", "🦌", "🦁", "🐯", "🐘", "🐍", "🦑", "🐻", "🐯", "🐼"]
priority_species1 = ["🐯", "🦌", "🐘", "🦁"]

observed_species2 = ["bluejay", "sparrow", "cardinal", "robin", "crow"]
priority_species2 = ["cardinal", "sparrow", "bluejay"]

print(prioritize_observations(observed_species1, priority_species1))
print(prioritize_observations(observed_species2, priority_species2))
# Out:
# ['🐍', '🐘', '🐯', '🐯', '🐯', '🐻', '🐼', '🦁', '🦁', '🦌', '🦑']
# ['bluejay', 'cardinal', 'crow', 'robin', 'sparrow']
